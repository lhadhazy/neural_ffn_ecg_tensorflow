# %%
import pywt
import pywt.data
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from scipy import signal

# %%
df=pd.read_csv('100.csv', sep=',',header=0, parse_dates=[0],  squeeze=False)
#df.drop(df.index[:1], inplace=True)

#f.Datetime=pd.to_datetime(df.Elapsed)
#df.set_index('Elapsed')
plt.figure(figsize=(10,10))
plt.plot(df['MLII'].head(300))

#plt.plot(df)
#plt.legend(['Original signal'])

# %%
# Oprions: 'V5' or 'MLII'
df.drop(df.index[:1], inplace=True)
#print(df.dtypes)
x=df[['MLII']].head(300).stack().values.flatten()
#plt.plot(x)
x
# Out:
# array([-0.41 , -0.41 , -0.41 , -0.41 , -0.4  , -0.385, -0.37 , -0.375,
#        -0.36 , -0.365, -0.355, -0.335, -0.315, -0.315, -0.31 , -0.315,
#        -0.295, -0.29 , -0.27 , -0.285, -0.29 , -0.29 , -0.28 , -0.275,
#        -0.255, -0.27 , -0.275, -0.275, -0.28 , -0.255, -0.245, -0.26 ,
#        -0.255, -0.265, -0.26 , -0.26 , -0.24 , -0.25 , -0.26 , -0.275,
#        -0.265, -0.26 , -0.26 , -0.285, -0.285, -0.28 , -0.285, -0.285,
#        -0.265, -0.28 , -0.275, -0.295, -0.295, -0.28 , -0.275, -0.28 ,
#        -0.285, -0.31 , -0.305, -0.28 , -0.29 , -0.285, -0.29 , -0.3  ,
#        -0.31 , -0.295, -0.295, -0.29 , -0.315, -0.31 , -0.31 , -0.315,
#        -0.305, -0.31 , -0.32 , -0.325, -0.31 , -0.305, -0.31 , -0.305,
#        -0.315, -0.315, -0.305, -0.305, -0.3  , -0.3  , -0.315, -0.32 ,
#        -0.305, -0.295, -0.3  , -0.305, -0.3  , -0.32 , -0.31 , -0.305,
#        -0.295, -0.3  , -0.31 , -0.325, -0.315, -0.315, -0.3  , -0.3  ,
#        -0.31 , -0.32 , -0.315, -0.305, -0.3  , -0.3  , -0.3  , -0.3  ,
#        -0.285, -0.26 , -0.245, -0.24 , -0.245, -0.25 , -0.24 , -0.245,
#        -0.23 , -0.22 , -0.23 , -0.235, -0.23 , -0.205, -0.2  , -0.195,
#        -0.21 , -0.215, -0.205, -0.205, -0.205, -0.21 , -0.225, -0.23 ,
#        -0.225, -0.22 , -0.22 , -0.215, -0.2  , -0.19 , -0.19 , -0.205,
#        -0.225, -0.25 , -0.27 , -0.3  , -0.305, -0.32 , -0.32 , -0.325,
#        -0.335, -0.34 , -0.335, -0.345, -0.33 , -0.33 , -0.345, -0.345,
#        -0.35 , -0.335, -0.335, -0.335, -0.34 , -0.345, -0.34 , -0.32 ,
#        -0.325, -0.325, -0.335, -0.345, -0.35 , -0.395, -0.43 , -0.46 ,
#        -0.505, -0.545, -0.575, -0.56 , -0.455, -0.33 , -0.235, -0.13 ,
#         0.   ,  0.16 ,  0.35 ,  0.545,  0.7  ,  0.815,  0.93 ,  1.035,
#         1.05 ,  0.92 ,  0.57 ,  0.115, -0.245, -0.42 , -0.425, -0.39 ,
#        -0.355, -0.36 , -0.365, -0.355, -0.35 , -0.36 , -0.365, -0.39 ,
#        -0.385, -0.375, -0.37 , -0.37 , -0.38 , -0.395, -0.385, -0.375,
#        -0.365, -0.37 , -0.385, -0.4  , -0.385, -0.385, -0.37 , -0.375,
#        -0.385, -0.395, -0.39 , -0.37 , -0.36 , -0.36 , -0.365, -0.37 ,
#        -0.37 , -0.365, -0.355, -0.36 , -0.37 , -0.38 , -0.38 , -0.365,
#        -0.37 , -0.365, -0.38 , -0.39 , -0.38 , -0.38 , -0.365, -0.365,
#        -0.375, -0.385, -0.385, -0.375, -0.36 , -0.355, -0.37 , -0.375,
#        -0.37 , -0.37 , -0.355, -0.365, -0.36 , -0.385, -0.385, -0.38 ,
#        -0.36 , -0.365, -0.375, -0.38 , -0.37 , -0.37 , -0.37 , -0.36 ,
#        -0.385, -0.395, -0.38 , -0.375, -0.365, -0.375, -0.385, -0.39 ,
#        -0.375, -0.37 , -0.37 , -0.37 , -0.37 , -0.385, -0.38 , -0.385,
#        -0.37 , -0.37 , -0.37 , -0.38 , -0.37 , -0.345, -0.34 , -0.325,
#        -0.335, -0.325, -0.305, -0.295])

# %% [markdown]
# # Denoise - Butterworth

# %%
# Butterworth filter: x -> y
lowcut=0.01
highcut=15.0
signal_freq=360
filter_order=1
plt.figure(figsize=(10,10))
nyquist_freq = 0.5*signal_freq
low=lowcut/nyquist_freq
high=highcut/nyquist_freq

b, a = signal.butter(filter_order, [low,high], btype="band")
y = signal.lfilter(b, a, x)
plt.plot(y)

# %% [markdown]
# # Baseline removal

# %%
#scipy.signal.butter(N, Wn, btype='low', analog=False, output='ba')[source]¶
#scipy.signal.firls(numtaps, bands, desired, weight=None, nyq=125, fs=250)

import peakutils
plt.figure(figsize=(10,10))

baseline_values = peakutils.baseline(y)

z = y-baseline_values

plt.plot(z)

# %% [markdown]
# # Wavelet decomposition

# %%
# x , y or z

w = pywt.Wavelet('db4')
#print(w.dec_lo)
plt.plot(w.dec_lo)
plt.plot(w.dec_hi)
plt.plot(w.rec_lo)
plt.plot(w.dec_hi)
coeffs = pywt.wavedec(x, w )
len(coeffs)
#print(coeffs)
#cA, cD = pywt.dwt(x, 'db4')
#cA5, cD5, cD4, cD3, cD2, cD1 = coeffs
#cA5
# Out:
# 6

# %%
coeffs[1]
# Out:
# array([ 9.94121412e-05, -2.48808207e-03, -6.19705863e-02,  1.54552426e-01,
#        -9.01547637e-02,  5.94802229e-02,  8.59658570e-02,  5.53786890e-02,
#         1.82720994e+00, -1.00482653e+00,  3.11561297e-01, -1.50724740e-01,
#         2.44910754e-02, -9.31327639e-03,  9.12254843e-02, -6.39124928e-03])

# %%
len(coeffs[3])
# Out:
# 43

# %%
plt.figure(figsize=(12,12))
def reconstruction_plot(yyy, **kwargs):
    """Plot signal vector on x [0,1] independently of amount of values it contains."""
    plt.plot(np.linspace(0, 1, len(yyy)), yyy, **kwargs)

reconstruction_plot(pywt.waverec(coeffs, w)) # full reconstruction 
#reconstruction_plot(pywt.waverec(coeffs[:-1] + [None] * 1, w)) # leaving out detail coefficients up to lvl 5
#reconstruction_plot(pywt.waverec(coeffs[:-2] + [None] * 2, w)) # leaving out detail coefficients up to lvl 4
#reconstruction_plot(pywt.waverec(coeffs[:-3] + [None] * 3, w)) # leaving out detail coefficients up to lvl 3
reconstruction_plot(pywt.waverec(coeffs[:-4] + [None] * 4, w)) # leaving out detail coefficients up to lvl 2
reconstruction_plot(pywt.waverec(coeffs[:-5] + [None] * 5, w)) # leaving out detail coefficients up to lvl 1
#reconstruction_plot(pywt.waverec(coeffs[:-6] + [None] * 6, w)) # leaving out all detail coefficients = reconstruction using lvl1 approximation only
plt.legend(['Full reconstruction', 'Reconstruction using detail coefficients lvl 1+2', 'Reconstruction using lvl 1 approximation only'])

# %%
plt.stem(coeffs[1]); plt.legend(['Lvl 1 detail coefficients'])

# %%
plt.stem(coeffs[2]); plt.legend(['Lvl 2 detail coefficients'])

# %%
plt.stem(coeffs[3]); plt.legend(['Lvl 3 detail coefficients'])

# %%
plt.stem(coeffs[4]); plt.legend(['Lvl 4 detail coefficients'])

# %%
plt.stem(coeffs[5]); plt.legend(['Lvl 5 detail coefficients'])

# %%
plt.stem(coeffs[6]); plt.legend(['Lvl 6 detail coefficients'])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-60-b8ac0442d46b> in <module>()
# ----> 1 plt.stem(coeffs[6]); plt.legend(['Lvl 6 detail coefficients'])
#
# IndexError: list index out of range

# %%
# Reconstruction of signal using just lvl1 approximation
approx_lvl1 = pywt.waverec(coeffs[:-3] + [None] * 3, w)
# interpolate to original amount of samples (necessary due to numeric solution of transformation not yielding same amount of values)
approx_lvl1_interp = np.interp(x=np.arange(0, 300), xp=np.linspace(0, 300, len(approx_lvl1)), fp=approx_lvl1)
x_without_lvl1approx = x - approx_lvl1_interp

# %%
def reconstruction_stem(yyy, **kwargs):
    """Plot coefficient vector on x [0,1] independently of amount of values it contains."""
    plt.stem(np.linspace(0, 1, len(yyy)), yyy, **kwargs)

plt.figure(figsize=(10,8))
reconstruction_plot(x, color='orange')
reconstruction_plot(x_without_lvl1approx, color='red')
reconstruction_stem(coeffs[3])
plt.legend(['Original signal', 'Original signal - lvl1 approximation', 'Detail coefficients'])

# %% [markdown]
# # PSD

# %%
from scipy import signal

fs = 10.0

# %%
# sig or z

sig=df[['V5']].head(256).stack().values.flatten()
reqs, times, spectrogram = signal.spectrogram(z)

plt.figure(figsize=(5, 5))
plt.imshow(spectrogram, aspect='auto', cmap='hot_r', origin='lower')
plt.title('Spectrogram')
plt.ylabel('Frequency band')
plt.xlabel('Time window')
plt.tight_layout()

# %%
# sig or z

freqs, psd = signal.welch(y)

plt.figure(figsize=(5, 4))
plt.semilogx(freqs, psd)
plt.title('PSD: power spectral density')
plt.xlabel('Frequency')
plt.ylabel('Power')
plt.tight_layout()

# %%
# sig or z

from spectrum import pmusic
p = pmusic(z, 128, NFFT=4128)
p.plot()

# %%
# pev :    Class to create PSD using ARMA estimator.
# pcovar:  Class to create PSD based on covariance algorithm
# eigen:   Pseudo spectrum using eigenvector method (EV or Music)

from spectrum import pev, pcovar, eigen
from pylab import plot, log10, linspace, legend, axis
#p = pev(sig, 128, NFFT=256)
#p = pcovar(sig, 128, NFFT=256)

psd, ev = eigen(y, 32, method='music' , NSIG=31,   NFFT=256)
f = linspace(0, 3, len(psd))
plot(f, 10 * log10(psd/max(psd)), label='User defined')


max(10 * log10(psd/max(psd)))

# %%
ev

# %% [markdown]
# # Lyapunov exponent

# %%
import nolds
x=df[['MLII']].head(2500).stack().values.flatten()
h = nolds.lyap_e(x)

plt.figure(figsize=(10,10))
plt.plot(h)

# %% [markdown]
# # Poincare Plot

# %%
import numpy as np
import matplotlib.pyplot as plt

def showTimeSeries(ts):
	x = np.arange(len(ts))
	plt.plot(x,ts)
	return

def showSMatrix(ts):
	angle,mag = PoincareVect(ts)
	img = aMatrix(angle,delay=1)	
	plt.imshow(img)
	return

def timeS2Poincare(ts,ndelay=1):
    x = ts[0:-2*ndelay]
    y = ts[ndelay:-ndelay]
    return x,y

def showPoincare(ts):
    x,y = timeS2Poincare(ts)
    plt.plot(x,y,'r.')
    return

def PoincareVect(ts,ndelay=1):
    x1 = ts[0:-2*ndelay]
    x2 = y1 = ts[ndelay:-ndelay]
    y2 = ts[2*ndelay:]
    deltax = x2-x1
    deltay = y2-y1
    angle = np.arctan2(deltax, deltay) * 180 / np.pi    
    angle = np.where(angle < 0, angle+360,angle)
    angle = angle / 18
    mag = (deltax**2 + deltay**2)**0.5    
    return angle,mag

def showPoincareVect(ts):
	angle,mag = PoincareVect(ts)
	sm = sMatrix(angle,mag)
	x_pos = np.arange(20)
	plt.bar(x_pos, sm)

	return

def showPoincareVect2(ts):
    angle,mag = PoincareVect(ts)
    plt.plot(mag,'r')

    return

def sMatrix(angle,mag):
    smat = np.zeros(20)
    for j in range (angle.shape[0]):
        smat[int(angle[j])] += mag[j]
        
    return (smat / smat.max())

def aMatrix(angle,delay=1):
    amat = np.zeros((20,20))
    for i in range(angle.shape[0]-delay):
        amat[int(angle[i]),int(angle[i+delay])] +=1
    return amat / amat.max()

# %%
showTimeSeries(z)

# %%
showPoincare(x)

# %%
showPoincare(z)

# %%
showPoincareVect(x)

# %%
showPoincareVect(z)

# %%
showSMatrix(x)

# %%
showSMatrix(z)

# %%
df=pd.read_csv('100_ALL_samples.csv', sep=',',header=0, parse_dates=[0],  squeeze=False)

#df.drop(df.index[:1], inplace=True)

print
#f.Datetime=pd.to_datetime(df.Elapsed)
#df.set_index('Elapsed')
plt.figure(figsize=(5,5))
plt.plot(df['MLII'].head(300))

#plt.plot(df)
#plt.legend(['Original signal'])

# %%
dfall=pd.read_csv('100_ALL_samples.csv', sep=',',header=0,   squeeze=False)
dfseg=pd.read_csv('100_ALL_QRS_csv.csv', sep=',',header=0, parse_dates=[0],  squeeze=False)
dfann=pd.read_csv('100_ALL_ANN.csv', sep=',',header=0, parse_dates=[0],  squeeze=False)
dfrri=pd.read_csv('100_ALL_RRI.csv', sep=',',header=0)
#df.drop(df.index[:1], inplace=True)

pattern = '[()]p.*p[)]'
dfseg['Type'].str.contains('p')
dfnew = dfseg.reset_index().groupby('Type')['index'].apply(np.array)
dfnew2 = dfseg.reset_index().groupby('Type')['sample'].apply(np.array)
pos = dfnew['p'][1]
dfnew['('][pos]
alist = dfnew['(']
blist = dfnew[')']
[ n for n,i in enumerate(alist) if i> pos][0]
#dfnew
#dfnew2
#x=dfseg[['Type']].head(300).stack().values.flatten()
#x

#for_new_df =[]
begList = [];
endList = [];
sliceList = [];

for x in dfnew['p']:
    #print(x)
    pbegin = [ n for n,i in enumerate(alist) if i> x][0]-1
    pend = pbegin-1
    #print(dfseg['sample'][pbegin])
    begList.append(pbegin);
    endList.append(pend);

#begList 
endList = endList[1:]
mixList = tuple(zip(begList,endList)) 

for x in mixList:
    #print(x)
    sliceList.append(tuple((dfnew2['('][x[0]],dfnew2[')'][x[1]])))

sliceList

#dfall['MLII'].head(10)
plt.figure(figsize=(24,8))

#plt.plot(dfall['MLII'].head(300))


#dfall['sample'].between(sliceList[0][0],sliceList[0][1], inclusive=True)
(dfall['sample'] >= -0.5) & (dfall['sample'] < 0.5)

for x in range(0,7):
    dfseg1 = dfall[(dfall['sample'] >= sliceList[x][0]) & (dfall['sample'] <= sliceList[x][1])]
    plt.title('Dataset 100 - First seven beats', color="grey")
    plt.plot(dfseg1['MLII'], color="blue")
    plt.plot(dfseg1['V5'], color="red")

# %%
fig, axes = plt.subplots(nrows=3, ncols=3, figsize = (15,15))

                 
y = -1
for x in range(0,9):
    if x % 3 == 0:
        y=y+1
    dfseg1 = dfall[(dfall['sample'] >= sliceList[x][0]) & (dfall['sample'] <= sliceList[x][1])]
    
    if str(dfrri['Type'][x]) != 'N':
        axes[y, x % 3].set_title('my title', color="red")
    else:
        axes[y, x % 3].set_title('my title', color="green")
  
    axes[y, x % 3].plot(dfseg1['MLII'], color="blue")
    axes[y, x % 3].plot(dfseg1['V5'], color="red")
    axes[y, x % 3].set_title(str(dfrri['Type'][x]) + ' (Rpeak: ' + str(dfann['sample'][x]) + ', PreRRI:' + str(float("{0:.4f}".format(dfrri['wPre'][x]))) + ')' )
